# %%
import pandas as pd
import json
import pickle
from gseapy.parser import gsea_gmt_parser

# %%
with open("../kegg.json", "r") as f:
    pathway_names = json.load(f)
    
kegg_pathway = gsea_gmt_parser("../kegg.gmt")

# %% [markdown]
# ### Co-expression network ORA

# %%
with open("../scz_bpd_co-exp_edges.pkl", "rb") as f:
    scz_bpd_edges = pickle.load(f)

with open("../t2dm_co-exp_edges.pkl", "rb") as f:
    dm_edges = pickle.load(f)
    
all_edge_intersection = scz_bpd_edges.intersection(dm_edges)
    
scz_bpd_df = pd.read_table("../../results/Supplementary Tables/STable 4. ORA of SCZ and BPD co-expression network.tsv", sep="\t")
dm_df = pd.read_table("../../results/Supplementary Tables/STable 5. ORA of T2DM co-expression network.tsv", sep="\t")

for path in set(scz_bpd_df["KEGG Pathway ID"]).intersection(set(dm_df["KEGG Pathway ID"])):
    overlapping_genes = all_edge_intersection.intersection(set(kegg_pathway[path]))
    if overlapping_genes:
        print(f'{pathway_names[path].replace(" - Homo sapiens (human)", "")}: {", ".join(overlapping_genes)}')
# Out:
# Human T-cell leukemia virus 1 infection: DLG1
# Proteasome: PSMD8
# Spinocerebellar ataxia: PSMD8
# Alzheimer disease: PSMD8
# RNA transport: EIF3A
# Epstein-Barr virus infection: PSMD8
# PI3K-Akt signaling pathway: YWHAQ
# Influenza A: KPNA1
# Endocytosis: CHMP5
# Huntington disease: PSMD8
# Parkinson disease: PSMD8

# %% [markdown]
# ### Knowledge graph ORA

# %%
sc_bel_df = pd.read_table("../../Knowledge Graphs/schizophrenia_kg.tsv")
bp_bel_df = pd.read_table("../../Knowledge Graphs/bipolar_disorder_kg.tsv")
dm_bel_df = pd.read_table("../../Knowledge Graphs/t2dm_kg.tsv")

sc_common_edges = [(sc_bel_df.at[row, "source"], sc_bel_df.at[row, "target"]) for row in sc_bel_df.index]
bp_common_edges = [(bp_bel_df.at[row, "source"], bp_bel_df.at[row, "target"]) for row in bp_bel_df.index]
dm_common_edges = [(dm_bel_df.at[row, "source"], dm_bel_df.at[row, "target"]) for row in dm_bel_df.index]

sc_set = {node for edge in sc_common_edges for node in edge}
bp_set = {node for edge in bp_common_edges for node in edge}
dm_set = {node for edge in dm_common_edges for node in edge}

# %%
all_gene_intersection = sc_set.intersection(bp_set.intersection(dm_set))
    
scz_df = pd.read_table("../../results/Supplementary Tables/STable 7. Pathway enrichment of schizophrenia KG.tsv", sep="\t")
bpd_df = pd.read_table("../../results/Supplementary Tables/STable 8. Pathway enrichment of bipolar KG.tsv", sep="\t")
dm_df = pd.read_table("../../results/Supplementary Tables/STable 9. Pathway enrichment of T2DM KG.tsv", sep="\t")

for path in set(scz_df["KEGG Pathway ID"]).intersection(set(bpd_df["KEGG Pathway ID"]).intersection(set(dm_df["KEGG Pathway ID"]))):
    overlapping_genes = all_gene_intersection.intersection(set(kegg_pathway[path]))
    if overlapping_genes:
        print(f'{pathway_names[path].replace(" - Homo sapiens (human)", "")}: {", ".join(overlapping_genes)}')
# Out:
# Tuberculosis: AKT1, IL6, CASP3, TNF, IL1A, NFKB1
# Acute myeloid leukemia: AKT1, STAT3, NFKB1
# C-type lectin receptor signaling pathway: AKT1, IL6, TNF, NFKB1, PTGS2
# Cocaine addiction: BDNF, NFKB1
# Hepatitis B: AKT1, IL6, CASP3, TNF, CXCL8, STAT3, NFKB1
# Longevity regulating pathway - multiple species: AKT1, IRS1, SOD2
# Yersinia infection: AKT1, IL6, CCL2, TNF, CXCL8, NFKB1
# Fc gamma R-mediated phagocytosis: AKT1
# Central carbon metabolism in cancer: AKT1
# Platinum drug resistance: CASP3, AKT1
# Insulin secretion: GLP1R
# Fluid shear stress and atherosclerosis: AKT1, CCL2, ICAM1, TNF, IL1A, NFKB1
# Prion diseases: IL1A, IL6, C5
# Viral protein interaction with cytokine and cytokine receptor: TNF, IL6, CCL2, CXCL8
# Alzheimer disease: AKT1, IL6, IRS1, MAPT, CASP3, TNF, IL1A, NFKB1, PTGS2
# Renal cell carcinoma: AKT1
# Sphingolipid signaling pathway: AKT1, NFKB1, TNF
# Amoebiasis: IL6, CASP3, TNF, CXCL8, NFKB1
# Rheumatoid arthritis: IL6, CCL2, ICAM1, TNF, CXCL8, IL1A
# Toxoplasmosis: AKT1, CASP3, TNF, STAT3, NFKB1
# NOD-like receptor signaling pathway: IL6, CCL2, TNF, CXCL8, NFKB1
# Chemical carcinogenesis: PTGS2
# Progesterone-mediated oocyte maturation: AKT1
# Chronic myeloid leukemia: AKT1, NFKB1
# Insulin signaling pathway: SOCS3, PPARGC1A, IRS1, AKT1
# Thermogenesis: PPARGC1A
# p53 signaling pathway: CASP3
# Choline metabolism in cancer: AKT1
# Human papillomavirus infection: AKT1, CASP3, TNF, NFKB1, PTGS2
# VEGF signaling pathway: AKT1, PTGS2
# Bladder cancer: CXCL8
# Leishmaniasis: TNF, IL1A, PTGS2, NFKB1
# Cytosolic DNA-sensing pathway: IL6, NFKB1
# Oxytocin signaling pathway: PTGS2
# Human T-cell leukemia virus 1 infection: AKT1, IL6, ICAM1, TNF, NFKB1
# Human immunodeficiency virus 1 infection: CASP3, AKT1, NFKB1, TNF
# Cholinergic synapse: AKT1, KCNQ1
# Signaling pathways regulating pluripotency of stem cells: AKT1, STAT3
# Colorectal cancer: CASP3, AKT1
# Type I diabetes mellitus: TNF, IL1A
# Endometrial cancer: AKT1
# Breast cancer: AKT1
# Chemokine signaling pathway: AKT1, CCL2, CXCL8, STAT3, NFKB1
# Estrogen signaling pathway: AKT1
# Growth hormone synthesis, secretion and action: AKT1, IRS1, SOCS3, GHRL, STAT3
# Viral myocarditis: CASP3, ICAM1
# Cholesterol metabolism: ABCA1
# T cell receptor signaling pathway: AKT1, NFKB1, TNF
# Hypertrophic cardiomyopathy (HCM): TNF, IL6
# Melanoma: AKT1
# TGF-beta signaling pathway: TNF, HAMP
# Small cell lung cancer: CASP3, AKT1, PTGS2, NFKB1
# JAK-STAT signaling pathway: AKT1, LEPR, IL6, SOCS3, STAT3, LEP
# Amyotrophic lateral sclerosis (ALS): CASP3, TNF
# Kaposi sarcoma-associated herpesvirus infection: AKT1, IL6, CASP3, ICAM1, CXCL8, STAT3, NFKB1, PTGS2
# Necroptosis: TNF, STAT3, IL1A
# AGE-RAGE signaling pathway in diabetic complications: AKT1, IL6, CCL2, CASP3, ICAM1, TNF, CXCL8, IL1A, STAT3, NFKB1
# TNF signaling pathway: AKT1, IL6, CCL2, SOCS3, ICAM1, CASP3, TNF, NFKB1, PTGS2
# Leukocyte transendothelial migration: ICAM1
# Transcriptional misregulation in cancer: IL6, NFKB1, CXCL8
# Platelet activation: AKT1
# Serotonergic synapse: CASP3, PTGS2
# MAPK signaling pathway: AKT1, BDNF, MAPT, CASP3, TNF, IL1A, NFKB1
# ErbB signaling pathway: AKT1
# Longevity regulating pathway: AKT1, PPARGC1A, IRS1, SOD2, ADIPOQ, NFKB1
# Hematopoietic cell lineage: TNF, IL6, IL1A
# Aldosterone-regulated sodium reabsorption: IRS1
# Prostate cancer: AKT1, NFKB1
# Adipocytokine signaling pathway: AKT1, LEPR, PPARGC1A, IRS1, SOCS3, TNF, ADIPOQ, STAT3, NFKB1, LEP
# Pathogenic Escherichia coli infection: IL6, CASP3, TNF, CXCL8, NFKB1
# Neuroactive ligand-receptor interaction: LEPR, GHRL, LEP, GLP1R, C5
# Osteoclast differentiation: AKT1, SOCS3, TNF, IL1A, NFKB1
# Natural killer cell mediated cytotoxicity: CASP3, ICAM1, TNF
# Measles: AKT1, IL6, CASP3, IL1A, STAT3, NFKB1
# B cell receptor signaling pathway: AKT1, NFKB1
# Malaria: IL6, CCL2, ICAM1, TNF, CXCL8
# Legionellosis: IL6, CASP3, TNF, CXCL8, NFKB1
# Relaxin signaling pathway: AKT1, NFKB1
# Hepatitis C: AKT1, SOCS3, CASP3, TNF, STAT3, NFKB1
# Epithelial cell signaling in Helicobacter pylori infection: CASP3, NFKB1, CXCL8
# Salmonella infection: AKT1, IL6, CASP3, TNF, CXCL8, NFKB1
# Chagas disease (American trypanosomiasis): AKT1, IL6, CCL2, TNF, CXCL8, NFKB1
# AMPK signaling pathway: AKT1, LEPR, PPARGC1A, IRS1, ADIPOQ, LEP
# mTOR signaling pathway: AKT1, IRS1, TNF
# FoxO signaling pathway: AKT1, IL6, IRS1, SOD2, STAT3
# Antifolate resistance: TNF, IL6, NFKB1, MTHFR
# Proteoglycans in cancer: CASP3, STAT3, AKT1, TNF
# Th17 cell differentiation: IL6, NFKB1, STAT3
# Non-small cell lung cancer: AKT1, STAT3
# Human cytomegalovirus infection: AKT1, IL6, CCL2, CASP3, TNF, CXCL8, STAT3, NFKB1, PTGS2
# PPAR signaling pathway: ADIPOQ
# Epstein-Barr virus infection: AKT1, IL6, CASP3, ICAM1, TNF, STAT3, NFKB1
# RIG-I-like receptor signaling pathway: TNF, NFKB1, CXCL8
# Adrenergic signaling in cardiomyocytes: AKT1, KCNQ1
# IL-17 signaling pathway: IL6, CCL2, CASP3, TNF, CXCL8, NFKB1, PTGS2
# Viral carcinogenesis: CASP3, STAT3, NFKB1
# Influenza A: AKT1, IL6, CCL2, SOCS3, ICAM1, CASP3, TNF, CXCL8, IL1A, NFKB1
# NF-kappa B signaling pathway: ICAM1, TNF, CXCL8, NFKB1, PTGS2
# Toll-like receptor signaling pathway: AKT1, IL6, TNF, CXCL8, NFKB1
# Cytokine-cytokine receptor interaction: LEPR, IL6, CCL2, TNF, CXCL8, IL1A, LEP
# Neurotrophin signaling pathway: AKT1, BDNF, IRS1, NFKB1
# cGMP-PKG signaling pathway: AKT1, IRS1
# Cellular senescence: AKT1, IL6, CXCL8, IL1A, NFKB1
# Prolactin signaling pathway: SOCS3, STAT3, AKT1, NFKB1
# Pancreatic cancer: AKT1, STAT3, NFKB1
# Glucagon signaling pathway: AKT1, PPARGC1A
# Ovarian steroidogenesis: PTGS2
# Autophagy - animal: AKT1, IRS1
# Herpes simplex virus 1 infection: AKT1, IL6, CCL2, SOCS3, CASP3, TNF, NFKB1, C5
# Glioma: AKT1
# Graft-versus-host disease: TNF, IL6, IL1A
# Thyroid hormone signaling pathway: AKT1
# cAMP signaling pathway: AKT1, BDNF, GHRL, NFKB1, GLP1R
# Dilated cardiomyopathy (DCM): TNF
# Pertussis: IL6, CASP3, TNF, CXCL8, IL1A, NFKB1, C5
# Dopaminergic synapse: AKT1, ARNTL, COMT
# Shigellosis: AKT1, NFKB1, CXCL8, TNF
# Endocrine resistance: AKT1
# Insulin resistance: AKT1, IL6, PPARGC1A, IRS1, SOCS3, TNF, STAT3, NFKB1
# Circadian rhythm: ARNTL
# Inflammatory bowel disease (IBD): IL6, TNF, IL1A, STAT3, NFKB1
# Complement and coagulation cascades: C5
# HIF-1 signaling pathway: AKT1, IL6, NFKB1, STAT3
# Hepatocellular carcinoma: AKT1
# Fc epsilon RI signaling pathway: AKT1, TNF
# Non-alcoholic fatty liver disease (NAFLD): AKT1, LEPR, IL6, IRS1, SOCS3, CASP3, TNF, CXCL8, ADIPOQ, IL1A, NFKB1, LEP
# Apelin signaling pathway: AKT1, PPARGC1A
# Staphylococcus aureus infection: ICAM1, C5
# EGFR tyrosine kinase inhibitor resistance: AKT1, IL6, STAT3
# Apoptosis: CASP3, AKT1, NFKB1, TNF
# PI3K-Akt signaling pathway: AKT1, IL6, BDNF, IRS1, NFKB1
# MicroRNAs in cancer: IRS1, CASP3, STAT3, NFKB1, PTGS2
# Type II diabetes mellitus: SOCS3, IRS1, ADIPOQ, TNF
# African trypanosomiasis: ICAM1, IL6, TNF
# Huntington disease: CASP3, PPARGC1A, SOD2, BDNF
# Phospholipase D signaling pathway: AKT1, CXCL8
# Gastric cancer: AKT1
# Th1 and Th2 cell differentiation: NFKB1
# Regulation of lipolysis in adipocytes: AKT1, IRS1, PTGS2
# PD-L1 expression and PD-1 checkpoint pathway in cancer: AKT1, STAT3, NFKB1
# Ras signaling pathway: AKT1, BDNF, NFKB1
